# %%
import sys
from pathlib import Path
import time
project_path = Path("/home/tolis/Desktop/tolis/DNN/project/DeepLearning_2024_2025_DSIT/")
sys.path.append(str(project_path))
from utils.PDFSerlalizer import DocumentHandler
image_dir = "/home/tolis/Desktop/tolis/DNN/project/DeepLearning_2024_2025_DSIT/kostas_ignore/output/"

# %%
pdf_file = "/home/tolis/Desktop/tolis/DNN/project/DeepLearning_2024_2025_DSIT/kostas_ignore/singapore-catalogue.pdf"
image_dir = "/home/tolis/Desktop/tolis/DNN/project/DeepLearning_2024_2025_DSIT/kostas_ignore/output/"

doc = DocumentHandler()
doc.extract_images(
    pdf_file,
    image_dir,
    verbose=True,
    export_pages=False,
    export_figures=True,
    export_tables=True,
    do_ocr=True,
    do_table_structure=True,
    add_caption=True,
    filter_irrelevant=True,
    generate_metadata=False,
    generate_annotated_pdf=False,
    generate_descriptions=False,
    generate_table_markdown=False,
    relevant_passages=2,
    prompt_passages=False
)
# Out:
# Processing PDF: /home/tolis/Desktop/tolis/DNN/project/DeepLearning_2024_2025_DSIT/kostas_ignore/singapore-catalogue.pdf...
# /home/tolis/miniconda3/envs/tolis/lib/python3.12/site-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Could not load the custom kernel for multi-scale deformable attention: /home/tolis/miniconda3/envs/tolis/bin/../lib/libstdc++.so.6: version `GLIBCXX_3.4.32' not found (required by /home/tolis/.cache/torch_extensions/py312_cu118/MultiScaleDeformableAttention/MultiScaleDeformableAttention.so)
# ...

# %%
from utils.ImageIndexer import ResNetIndexer, CLIPIndexer, ColpaliIndexer, visualize_results
index_dir = "/home/tolis/Desktop/tolis/DNN/project/DeepLearning_2024_2025_DSIT/kostas_ignore/indexes/"
index_dir = "/home/tolis/Desktop/tolis/DNN/project/DeepLearning_2024_2025_DSIT/kostas_ignore/indexes/"

resnet = ResNetIndexer(index_dir+"resnet")
clip = CLIPIndexer(index_dir+"clip")
colpali = ColpaliIndexer(index_dir+"colpali")

print("Creating indexes...")
print("ResNet")
resnet.create_index(image_dir)
print("CLIP")
clip.create_index(image_dir)
print("Byaldi")
colpali.create_index(image_dir)
# Out:
# Creating indexes...
# ResNet
# Indexing images: 100%|██████████| 31/31 [00:00<00:00, 39.16it/s]
# CLIP
# /home/tolis/.cache/huggingface/modules/transformers_modules/jinaai/jina-clip-implementation/51f02de9f2cf8afcd3bac4ce996859ba96f9f8e9/modeling_clip.py:140: UserWarning: Flash attention is not installed. Check https://github.com/Dao-AILab/flash-attention?tab=readme-ov-file#installation-and-features for installation instructions, disabling
#   warnings.warn(
# /home/tolis/.cache/huggingface/modules/transformers_modules/jinaai/jina-clip-implementation/51f02de9f2cf8afcd3bac4ce996859ba96f9f8e9/modeling_clip.py:175: UserWarning: xFormers is not installed. Check https://github.com/facebookresearch/xformers?tab=readme-ov-file#installing-xformers for installation instructions, disabling
#   warnings.warn(
# Indexing images: 100%|██████████| 8/8 [00:05<00:00,  1.52it/s]
# Byaldi
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# ...

# %%
index_dir = "/home/tolis/Desktop/tolis/DNN/project/DeepLearning_2024_2025_DSIT/kostas_ignore/indexes/"
query_image_path = "/home/tolis/Desktop/tolis/DNN/project/DeepLearning_2024_2025_DSIT/kostas_ignore/test.png"
image_dir = "/home/tolis/Desktop/tolis/DNN/project/DeepLearning_2024_2025_DSIT/kostas_ignore/output/"

# %%
results = resnet.query_by_image(query_image_path, index_dir+"resnet")
visualize_results(results)

# %%
results = clip.query_by_image(query_image_path, index_dir+"clip")
visualize_results(results)
# Out:
# /home/tolis/.cache/huggingface/modules/transformers_modules/jinaai/jina-clip-implementation/51f02de9f2cf8afcd3bac4ce996859ba96f9f8e9/modeling_clip.py:140: UserWarning: Flash attention is not installed. Check https://github.com/Dao-AILab/flash-attention?tab=readme-ov-file#installation-and-features for installation instructions, disabling
#   warnings.warn(
# /home/tolis/.cache/huggingface/modules/transformers_modules/jinaai/jina-clip-implementation/51f02de9f2cf8afcd3bac4ce996859ba96f9f8e9/modeling_clip.py:175: UserWarning: xFormers is not installed. Check https://github.com/facebookresearch/xformers?tab=readme-ov-file#installing-xformers for installation instructions, disabling
#   warnings.warn(

# %%
results = byaldi.query_by_image(query_image_path)
visualize_results(results)

# %%
text = "jewelries"
results = clip.query_by_text(text, index_dir+"clip")
visualize_results(results)

# %%
text = "jewelries"
results = byaldi.query_by_text(text)
visualize_results(results)
# Out:
# Querying with: jewelries
